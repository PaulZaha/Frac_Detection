B4_opt_loss = [0.48450279235839844, 0.3166402280330658, 0.2592710554599762, 0.2270747870206833, 0.205863818526268, 0.21168586611747742, 0.1727381944656372, 0.15733453631401062, 0.14751410484313965, 0.14553186297416687, 0.13322938978672028, 0.12886330485343933, 0.12581253051757812, 0.11623748391866684, 0.11174292862415314, 0.10975226759910583, 0.10823889821767807, 0.10487564653158188, 0.0938299372792244, 0.10222640621614456]
B4_opt_val_acc = [0.83915, 0.87209, 0.87694, 0.89341, 0.89632, 0.89632, 0.90795, 0.91085, 0.92151, 0.9099, 0.92151, 0.92926, 0.93314, 0.93314, 0.93314, 0.9109, 0.9244, 0.9264, 0.9205, 0.9254]
B4_opt_val_loss = [0.3691226544380188, 0.3036715099811554, 0.28734898591041565, 0.265619695186615, 0.24863262474536896, 0.23888246726989746, 0.2361585795879364, 0.22445489466190338, 0.20001381635665894, 0.20863176894187927, 0.1976126582622528, 0.18843753683567047, 0.1852358282804489, 0.19920308887958527, 0.18313358759880066, 0.20716018962860107, 0.1819974775314331, 0.201922997713089, 0.18324092030525208, 0.19923377013206482]


lr = [1.9999999494757503e-05,1.9999999494757503e-05,1.9999999494757503e-05,1.9999999494757503e-05,1.9999999494757503e-05,1.9999999494757503e-05,1.9999999494757503e-05,1.894740343093872e-05,1.77902235747084e-05,1.6706487247313076e-05,1.570466930384937e-05,1.472628663477155e-05,1.382683856561369e-05,1.2896650499033001e-05,1.1977955120466586e-05,1.0972866988435728e-05,1.0085630871035226e-05,9.184027286565862e-06,8.387587142831263e-06]

# %%
# Create a list of lists
lists = [resnet_acc, xception_acc, Inception_acc, Densenet_acc, B3_acc, B4_acc, B4_opt_acc]
list_names = ['resnet', 'xception', 'Inception', 'Densenet', 'B3', 'B4', 'B4_opt']

# Plotting
for i, data in enumerate(lists):
    print(len(lists[i]))
    plt.plot(data, label=list_names[i])

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.show()
# Out:
# 17
# 18
# 20
# 20
# 20
# 20
# 20

# %%
# Create a list of lists
lists = [resnet_loss, xception_loss, Inception_loss, Densenet_loss, B3_loss, B4_loss, B4_opt_loss]
list_names = ['resnet', 'xception', 'Inception', 'Densenet', 'B3', 'B4', 'B4_opt']

# Plotting
for i, data in enumerate(lists):
    print(len(lists[i]))
    plt.plot(data, label=list_names[i])

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.show()
# Out:
# 17
# 18
# 20
# 20
# 20
# 20
# 20

# %%
# Create a list of lists
lists = [resnet_val_acc, xception_val_acc, Inception_val_acc, Densenet_val_acc, B3_val_acc, B4_val_acc, B4_opt_val_acc]
list_names = ['resnet', 'xception', 'Inception', 'Densenet', 'B3', 'B4', 'B4_opt']

# Plotting
for i, data in enumerate(lists):
    print(len(lists[i]))
    plt.plot(data, label=list_names[i])

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.show()
# Out:
# 17
# 18
# 20
# 20
# 20
# 20
# 20

# %%
# Create a list of lists
lists = [resnet_val_loss, xception_val_loss, Inception_val_loss, Densenet_val_loss, B3_val_loss, B4_val_loss, B4_opt_val_loss]
list_names = ['resnet', 'xception', 'Inception', 'Densenet', 'B3', 'B4', 'B4_opt']

# Plotting
for i, data in enumerate(lists):
    print(len(lists[i]))
    plt.plot(data, label=list_names[i])

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.show()
# Out:
# 17
# 18
# 20
# 20
# 20
# 20
# 20

# %%
conf_matrix_b4_opt = np.array([[263, 22], [15, 274]]).T


sns.heatmap(conf_matrix_b4_opt, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["fractured", "non-fractured"],
            yticklabels=["fractured", "non-fractured"])

plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
# Create a list of lists
B4_acc = [0.7419, 0.8426, 0.8707, 0.8896, 0.9046, 0.9186, 0.9240, 0.9211, 0.9337, 0.9356, 0.9433, 0.9436, 0.9477, 0.9458, 0.9564, 0.9557, 0.9535, 0.9584, 0.9598, 0.9627]
B4_loss = [0.5284, 0.3712, 0.3164, 0.2798, 0.2503, 0.2247, 0.2091, 0.2046, 0.1884, 0.1824, 0.1716, 0.1610, 0.1536, 0.1512, 0.1401, 0.1372, 0.1348, 0.1293, 0.1276, 0.1209]
B4_val_acc = [0.7955, 0.8421, 0.8643, 0.8973, 0.9012, 0.8973, 0.9118, 0.9147, 0.9109, 0.9234, 0.9186, 0.9186, 0.9167, 0.9322, 0.9283, 0.9283, 0.9293, 0.9293, 0.9293, 0.9205]
B4_val_loss = [0.4294, 0.3548, 0.3197, 0.2712, 0.2669, 0.2485, 0.2319, 0.2261, 0.2248, 0.2171, 0.2091, 0.2051, 0.2021, 0.1996, 0.1919, 0.1850, 0.1846, 0.1749, 0.1767, 0.1827]


B4_opt_acc = [0.7666, 0.8717, 0.9015, 0.9104, 0.923, 0.9182, 0.9375, 0.9436, 0.9499, 0.9506, 0.9533, 0.9564, 0.9574,0.9622, 0.9634, 0.9668, 0.9678, 0.9671, 0.9726, 0.9663]
B4_opt_loss = [0.48450279235839844, 0.3166402280330658, 0.2592710554599762, 0.2270747870206833, 0.205863818526268, 0.21168586611747742, 0.1727381944656372, 0.15733453631401062, 0.14751410484313965, 0.14553186297416687, 0.13322938978672028, 0.12886330485343933, 0.12581253051757812, 0.11623748391866684, 0.11174292862415314, 0.10975226759910583, 0.10823889821767807, 0.10487564653158188, 0.0938299372792244, 0.10222640621614456]
B4_opt_val_acc = [0.83915, 0.87209, 0.87694, 0.89341, 0.89632, 0.89632, 0.90795, 0.91085, 0.92151, 0.9099, 0.92151, 0.92926, 0.93314, 0.93314, 0.93314, 0.9109, 0.9244, 0.9264, 0.9205, 0.9254]
B4_opt_val_loss = [0.3691226544380188, 0.3036715099811554, 0.28734898591041565, 0.265619695186615, 0.24863262474536896, 0.23888246726989746, 0.2361585795879364, 0.22445489466190338, 0.20001381635665894, 0.20863176894187927, 0.1976126582622528, 0.18843753683567047, 0.1852358282804489, 0.19920308887958527, 0.18313358759880066, 0.20716018962860107, 0.1819974775314331, 0.201922997713089, 0.18324092030525208, 0.19923377013206482]

lists = [B4_opt_acc,B4_opt_val_acc,B4_acc,B4_val_acc]
list_names = [ 'B4_opt_training','B4_opt_validation','B4_training','B4_validation']

# Plotting
for i, data in enumerate(lists):
    plt.plot(data, label=list_names[i])

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Show the plot
plt.show()

# %%
B4_acc = [0.7419, 0.8426, 0.8707, 0.8896, 0.9046, 0.9186, 0.9240, 0.9211, 0.9337, 0.9356, 0.9433, 0.9436, 0.9477, 0.9458, 0.9564, 0.9557, 0.9535, 0.9584, 0.9598, 0.9627]
B4_loss = [0.5284, 0.3712, 0.3164, 0.2798, 0.2503, 0.2247, 0.2091, 0.2046, 0.1884, 0.1824, 0.1716, 0.1610, 0.1536, 0.1512, 0.1401, 0.1372, 0.1348, 0.1293, 0.1276, 0.1209]
B4_val_acc = [0.7955, 0.8421, 0.8643, 0.8973, 0.9012, 0.8973, 0.9118, 0.9147, 0.9109, 0.9234, 0.9186, 0.9186, 0.9167, 0.9322, 0.9283, 0.9283, 0.9293, 0.9293, 0.9293, 0.9205]
B4_val_loss = [0.4294, 0.3548, 0.3197, 0.2712, 0.2669, 0.2485, 0.2319, 0.2261, 0.2248, 0.2171, 0.2091, 0.2051, 0.2021, 0.1996, 0.1919, 0.1850, 0.1846, 0.1749, 0.1767, 0.1827]


B4_opt_acc = [0.7666, 0.8717, 0.9015, 0.9104, 0.923, 0.9182, 0.9375, 0.9436, 0.9499, 0.9506, 0.9533, 0.9564, 0.9574,0.9622, 0.9634, 0.9668, 0.9678, 0.9671, 0.9726, 0.9663]
B4_opt_loss = [0.48450279235839844, 0.3166402280330658, 0.2592710554599762, 0.2270747870206833, 0.205863818526268, 0.21168586611747742, 0.1727381944656372, 0.15733453631401062, 0.14751410484313965, 0.14553186297416687, 0.13322938978672028, 0.12886330485343933, 0.12581253051757812, 0.11623748391866684, 0.11174292862415314, 0.10975226759910583, 0.10823889821767807, 0.10487564653158188, 0.0938299372792244, 0.10222640621614456]
B4_opt_val_acc = [0.83915, 0.87209, 0.87694, 0.89341, 0.89632, 0.89632, 0.90795, 0.91085, 0.92151, 0.9099, 0.92151, 0.92926, 0.93314, 0.93314, 0.93314, 0.9109, 0.9244, 0.9264, 0.9205, 0.9254]
B4_opt_val_loss = [0.3691226544380188, 0.3036715099811554, 0.28734898591041565, 0.265619695186615, 0.24863262474536896, 0.23888246726989746, 0.2361585795879364, 0.22445489466190338, 0.20001381635665894, 0.20863176894187927, 0.1976126582622528, 0.18843753683567047, 0.1852358282804489, 0.19920308887958527, 0.18313358759880066, 0.20716018962860107, 0.1819974775314331, 0.201922997713089, 0.18324092030525208, 0.19923377013206482]

lists = [B4_opt_loss,B4_opt_val_loss,B4_loss,B4_val_loss]
list_names = [ 'B4_opt_training','B4_opt_validation','B4_training','B4_validation']

# Plotting
for i, data in enumerate(lists):
    plt.plot(data, label=list_names[i])

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.show()

# %%
# Create a list of lists

# Plotting

plt.plot(lr,label="lr")

# Adding labels and legend
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
y_labels = ['{:.1e}'.format(value) for value in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], y_labels)

# Show the plot
plt.show()
